# %%
import cv2
import numpy as np

gt_mask = cv2.imread("Image5.png", cv2.IMREAD_GRAYSCALE)
gt_mask = (gt_mask > 0).astype(np.uint8) * 255

# %%
pred_mask = np.zeros_like(markers, dtype=np.uint8)
pred_mask[markers > 1] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pred_mask = np.zeros_like(markers, dtype=np.uint8)
#       2 pred_mask[markers > 1] = 1
#
# NameError: name 'markers' is not defined
