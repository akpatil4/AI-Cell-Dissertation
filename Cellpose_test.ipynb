# %% [markdown]
# <a href="https://colab.research.google.com/github/akpatil4/AI-Cell-Dissertation/blob/main/Cellpose_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cellpose
# !pip install tifffile
# Out:
# Collecting cellpose
#   Downloading cellpose-4.0.8-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose) (2025.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose) (4.67.1)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.12/dist-packages (from cellpose) (2.9.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose) (0.24.0+cpu)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose) (4.12.0.88)
# Collecting fastremap (from cellpose)
#   Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose)
#   Downloading imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting roifile (from cellpose)
#   Downloading roifile-2026.1.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting fill-voids (from cellpose)
#   Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting segment_anything (from cellpose)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6->cellpose) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6->cellpose) (3.0.3)
# Downloading cellpose-4.0.8-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 2.2 MB/s eta 0:00:00
# Downloading fastremap-1.17.7-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 13.8 MB/s eta 0:00:00
# Downloading fill_voids-2.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.0 MB/s eta 0:00:00
# Downloading imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 15.4 MB/s eta 0:00:00
# Downloading roifile-2026.1.8-py3-none-any.whl (16 kB)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Installing collected packages: segment_anything, roifile, imagecodecs, fastremap, fill-voids, cellpose
# Successfully installed cellpose-4.0.8 fastremap-1.17.7 fill-voids-2.1.1 imagecodecs-2026.1.14 roifile-2026.1.8 segment_anything-1.0
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (2025.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tifffile) (2.0.2)

# %%
# !pip install cellpose==3.0.5
# Out:
# Collecting cellpose==3.0.5
#   Downloading cellpose-3.0.5-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (2025.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (4.67.1)
# Requirement already satisfied: numba>=0.53.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (0.60.0)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (0.43.0)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (2.9.0+cpu)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (4.12.0.88)
# Requirement already satisfied: fastremap in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (1.17.7)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (2026.1.14)
# Requirement already satisfied: roifile in /usr/local/lib/python3.12/dist-packages (from cellpose==3.0.5) (2026.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->cellpose==3.0.5) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6->cellpose==3.0.5) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6->cellpose==3.0.5) (3.0.3)
# Downloading cellpose-3.0.5-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: cellpose
#   Attempting uninstall: cellpose
#     Found existing installation: cellpose 4.0.8
#     Uninstalling cellpose-4.0.8:
#       Successfully uninstalled cellpose-4.0.8
# Successfully installed cellpose-3.0.5

# %%
 # Pre-trained Cellpose model - weights from Stringer et al. (2021)
from cellpose import models
model = models.CellposeModel(model_type='cyto2', gpu=False)
# Out:
# 100%|██████████| 25.3M/25.3M [00:03<00:00, 8.56MB/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
from cellpose import models, io
from cellpose.io import imread

io.logger_setup()

model = models.CellposeModel(gpu=True)

# %%
from cellpose import models, io , plot
import cv2
import os # Import os module to check for file existence

model = models.Cellpose(model_type= "cyto2")

#Evaluating segmentation of red image
image_filename = "Image2.png"

# Check if the image file exists
if not os.path.exists(image_filename):
    print(f"ERROR: Image file '{image_filename}' not found.")
    print("Please ensure the image file is in the current directory or provide the correct path.")
    # Set img to None to handle the missing file case gracefully
    img = None
else:
    img = io.imread(image_filename)

# Only proceed with model evaluation if the image was successfully loaded
if img is not None:
    masks, flows, styles, diams = model.eval(
        img,
        channels=[0,0],

    )
    print("Segmentation completed successfully.")
else:
    print("Image not loaded, skipping segmentation.")
# Out:
# Segmentation completed successfully.

# %%
import matplotlib.pyplot as plt

# Show the segmented output of red
if 'masks' in locals() and masks is not None:
    plt.figure(figsize=(8, 8))
    plt.imshow(masks)
    plt.title("Cellpose Segmentation Masks")
    plt.axis("off")
    plt.show()
else:
    print("No masks to display. Please ensure segmentation was successful.")

# %%
model = models.Cellpose(model_type= "cyto2")

#Evaluating the segmentation of blue
image_filename = "Image3.png"

# Check if the image file exists
if not os.path.exists(image_filename):
    print(f"ERROR: Image file '{image_filename}' not found.")
    print("Please ensure the image file is in the current directory or provide the correct path.")
    # Set img to None to handle the missing file case gracefully
    img = None
else:
    img = io.imread(image_filename)

# Only proceed with model evaluation if the image was successfully loaded
if img is not None:
    masks, flows, styles, diams = model.eval(
        img,
        channels=[0,0],

    )
    print("Segmentation completed successfully.")
else:
    print("Image not loaded, skipping segmentation.")


if 'masks' in locals() and masks is not None:
    plt.figure(figsize=(8, 8))
    plt.imshow(masks)
    plt.title("Cellpose Segmentation Masks")
    plt.axis("off")
    plt.show()
else:
    print("No masks to display. Please ensure segmentation was successful.")
# Out:
# Segmentation completed successfully.

# %%
model = models.Cellpose(model_type= "cyto2")

# Conducting segmentation for orange channel
image_filename = "Image4.png"

# Check if the image file exists
if not os.path.exists(image_filename):
    print(f"ERROR: Image file '{image_filename}' not found.")
    print("Please ensure the image file is in the current directory or provide the correct path.")
    # Set img to None to handle the missing file case gracefully
    img = None
else:
    img = io.imread(image_filename)

# Only proceed with model evaluation if the image was successfully loaded
if img is not None:
    masks, flows, styles, diams = model.eval(
        img,
        channels=[0,0],

    )
    print("Segmentation completed successfully.")
else:
    print("Image not loaded, skipping segmentation.")


if 'masks' in locals() and masks is not None:
    plt.figure(figsize=(8, 8))
    plt.imshow(masks)
    plt.title("Cellpose Segmentation Masks")
    plt.axis("off")
    plt.show()
else:
    print("No masks to display. Please ensure segmentation was successful.")
# Out:
# Segmentation completed successfully.

# %%
model = models.Cellpose(model_type= "cyto2")

# Conducting segmentation for green channel
image_filename = "Image5.png"

# Check if the image file exists
if not os.path.exists(image_filename):
    print(f"ERROR: Image file '{image_filename}' not found.")
    print("Please ensure the image file is in the current directory or provide the correct path.")
    # Set img to None to handle the missing file case gracefully
    img = None
else:
    img = io.imread(image_filename)

# Only proceed with model evaluation if the image was successfully loaded
if img is not None:
    masks, flows, styles, diams = model.eval(
        img,
        channels=[0,0],

    )
    print("Segmentation completed successfully.")
else:
    print("Image not loaded, skipping segmentation.")


if 'masks' in locals() and masks is not None:
    plt.figure(figsize=(8, 8))
    plt.imshow(masks)
    plt.title("Cellpose Segmentation Masks")
    plt.axis("off")
    plt.show()
else:
    print("No masks to display. Please ensure segmentation was successful.")
# Out:
# Segmentation completed successfully.
